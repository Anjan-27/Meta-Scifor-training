# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
emp={'Age_Years':[1,23,22,25,20,23,24,27],
    'Salary_Thousand':[15,22,24,25,30,23,34,43]}

# %%
df=pd.DataFrame(emp)

# %%
df
# Out:
#    Age_Years  Salary_Thousand
# 0          1               15
# 1         23               22
# 2         22               24
# 3         25               25
# 4         20               30
# 5         23               23
# 6         24               34
# 7         27               43

# %%
#Boxplot

# %%
plt.figure(figsize=(5,6))
ax=sns.boxplot(data=df)
plt.yticks(range(5,60,5))#range on y asix
plt.xlabel('Age and Salary')
plt.show()

# %%
#Another way

# %%
df.plot(kind='box',figsize=(8,5),color='r',yticks=range(0,55,5))
# Out:
# <Axes: >

# %%
sal=[22,24,25,30,23,34,43,19,20]
sal.sort()
sal
# Out:
# [19, 20, 22, 23, 24, 25, 30, 34, 43]

# %% [markdown]
# ## Please see below Example
# [15,19,20,21,22,23,24,25,30,34,43,52]
#
# n=total elements in the above (12 items)
#
# --> 25%=(25/100) * (n+1)=3.25(data at 3.25 Position is the 25% percentile .lets say around 20.50)
#
# --> 50%=(50/100) * (n+1)=6.5(data at this position)
#
# --> 75%=(75/100) * (n+1)=9.75(data at this position)

# %% [markdown]
# ## Outliers

# %%
import pandas as pd
ser=pd.Series(sal)
ser
# Out:
# 0    19
# 1    20
# 2    22
# 3    23
# 4    24
# 5    25
# 6    30
# 7    34
# 8    43
# dtype: int64

# %%
#1st Quantile
q1=ser.quantile(0.25)
print('Q1',q1)
#3rd Quantile
q3=ser.quantile(0.75)
print('Q3',q3)
#Find the IQR (inter quantile range) to identify outliers
iqr=q3-q1
print('IQR',iqr)
# Out:
# Q1 22.0
# Q3 30.0
# IQR 8.0

# %% [markdown]
# ## Outliers
# higher side==> Q3 + (1.5 * IQR) lower side ==> Q1 - (1.5 * IQR)

# %%
upside=q3 + (1.5 * iqr)
print(upside)
# Out:
# 42.0

# %%
#Anything above 43.373 is outlier

# %%
lower_side=q1-(1.5 * iqr)
print(lower_side)
# Out:
# 10.0

# %%
#Anything below 5.375 is outlier

# %%
ser.plot(kind='box',figsize=(8,5),color='r',yticks=range(0,55,5))
# Out:
# <Axes: >

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from pandas.plotting import scatter_matrix

# %%
titanic=sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df=titanic.drop(['parch'],axis=1)

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp     fare embarked  class    who  \
# 0         0       3    male  22.0      1   7.2500        S  Third    man
# 1         1       1  female  38.0      1  71.2833        C  First  woman
# 2         1       3  female  26.0      0   7.9250        S  Third  woman
# 3         1       1  female  35.0      1  53.1000        S  First  woman
# 4         0       3    male  35.0      0   8.0500        S  Third    man
#
#    adult_male deck  embark_town alive  alone
# 0        True  NaN  Southampton    no  False
# 1       False    C    Cherbourg   yes  False
# 2       False  NaN  Southampton   yes   True
# 3       False    C  Southampton   yes  False
# 4        True  NaN  Southampton    no   True

# %%
titanic=sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
iris=sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#KDE-kernel density estimation
scatter_matrix(df,figsize=(10,8),color='r',diagonal='kde')
plt.show()

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
rupees_monthly=[2000,2530,900,1500,1500]
items=['Tution_Fee','Mobile_bill','Electricity_bill','Rent','Misc']

# %%
plt.pie(x=rupees_monthly,labels=items)
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.pie(x=rupees_monthly,labels=items,explode=[0,0,0,0.1,0],autopct='%2f',rotatelabels=True)
plt.show()

# %%
# Numerical Plotting

# %%
#--> relplot()
#--> Scatter Plot()
#--> inlineplot()

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
sns.relplot(x='total_bill',y='tip',data=tips)
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=tips,hue='smoker',style='time')
plt.show()

# %%
sns.relplot(x='total_bill',y='tip',data=tips,size='size')
plt.show()

# %%
sns.lineplot(x='total_bill',y='tip',data=tips)
plt.show()

# %% [markdown]
# ## Categorical plotting

# %% [markdown]
# --> Catplot() --> Bosplot() --> Striplot() --> Swarmplot()

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
#Catplot()

# %%
sns.catplot(x='day',y='total_bill',data=tips)
plt.show()

# %%
sns.swarmplot(x='day',y='total_bill',data=tips)
plt.show()

# %%
sns.catplot(x='day',y='total_bill',data=tips,kind='swarm',hue='size')

# %%
sns.stripplot(x='size',y='total_bill',data=tips)
plt.show()

# %%
sns.stripplot(x='smoker',y='total_bill',data=tips)
plt.show()

# %% [markdown]
# ## Visualizing Distribution of the data
#
# --> distplot()
#
# --> kdeplot()
#
# --> jointplot()

# %%
import seaborn as sns
import pandas as pd
from numpy.random import randn
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
x=randn(100)

# %%
x
# Out:
# array([ 3.75271280e-01, -2.09427487e-01,  4.02331271e-01, -8.13546634e-01,
#         1.32015531e+00, -4.89442172e-01, -1.18866736e+00, -1.20429037e+00,
#         3.26767359e-01, -1.15480037e+00, -2.48152032e-01, -1.42557754e+00,
#        -5.11453373e-01, -1.03339611e+00, -2.62749904e-01,  7.46686004e-01,
#         8.38909473e-01,  7.04575972e-01, -1.28715445e+00, -1.53213782e+00,
#        -1.83321647e+00, -5.76765406e-01, -1.91291657e+00, -5.50450072e-01,
#         7.35739130e-01,  1.87147857e+00, -3.76628815e-01,  4.00665541e-01,
#         8.28832779e-01,  1.57246487e+00,  2.89129178e+00, -2.33968338e-01,
#        -1.33125399e-03,  8.01645595e-01, -5.11308356e-02,  1.43460392e+00,
#         1.81224371e-02, -6.79436257e-01, -4.91029701e-01,  2.58381784e-01,
#         9.08497964e-01,  5.59746230e-01,  1.31892645e+00, -1.19462236e+00,
#         2.02720172e+00,  9.41600429e-02, -2.37579580e-01,  6.84927299e-02,
#        -5.57071607e-01,  1.88891499e-01, -7.60486881e-01, -1.81277976e+00,
#        -9.24371333e-01,  1.87827629e+00, -1.21861801e+00,  2.16929158e-01,
#        -1.17144544e+00, -6.62933423e-01,  1.93653156e+00,  1.56032315e+00,
#        -5.40034495e-01, -8.27096450e-01, -9.57219251e-02,  6.09580713e-01,
#        -1.60607666e+00, -1.89973308e-01,  7.28145263e-01, -3.56285043e-01,
#         3.87721766e-01,  9.50311645e-01,  5.09856467e-02, -7.35501873e-01,
#         1.61905467e+00,  2.28687739e+00, -8.45405477e-01, -4.10050820e-01,
#        -8.06042285e-01,  1.26222536e-01,  1.22114457e+00,  3.24283873e-01,
#        -1.36021516e-01, -2.37059778e-01,  2.99935903e-01, -1.50654202e-01,
#        -1.21769907e-02,  7.83750710e-01, -1.89290939e+00,  2.11746157e+00,
#        -1.82954177e+00,  2.99686885e-01,  1.45158479e+00, -1.36078960e+00,
#        -1.51049074e+00, -1.55602429e+00,  9.86938649e-01,  7.22078837e-01,
#         5.36465913e-01, -2.01070036e-01, -6.75368483e-01, -1.16946577e-01])

# %%
sns.distplot(x,kde=True,hist=False)
plt.show()

# %%
tist=sns.load_dataset('tips')
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
x=tips['total_bill']
y=tips['tip']

# %%
sns.jointplot(x=x,y=y)

# %% [markdown]
# ## Linear Regression and Relationship
# -->Regplot
#
# --> Implot

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
tips=sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.regplot(x='total_bill',y='tip',data=tips)
plt.show()

# %%
sns.lmplot(x='total_bill',y='tip',data=tips)
plt.show()
